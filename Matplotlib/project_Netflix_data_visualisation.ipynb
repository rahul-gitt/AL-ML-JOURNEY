# %%
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Desktop\\AL-ML-JOURNEY\\Matplotlib\\netflix_titles.csv")

# clean data
df = df.dropna(subset=['type', 'release_year', ])
