# %%
import matplotlib.pyplot as plt

regions= ['North', 'South', 'East', 'West']
sales= [20000, 7000, 26900, 9580]

plt.pie(sales, labels = regions, colors= ['gold', 'skyblue', 'lightgreen', 'coral'], autopct= '%1.1f%%')
plt.title("Region wise sales")
plt.show()
