# %%
import numpy as np

arr = np.array([10,20,np.nan, 30,40,np.nan,50])

clear_arr = arr[~np.isnan()arr]

print(clear_arr)
# Out:
#   Cell In[1], line 5
#     clear_arr = arr[~np.isnan()arr]
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
