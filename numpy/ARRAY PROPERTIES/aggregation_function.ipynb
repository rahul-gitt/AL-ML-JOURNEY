# %%
import numpy as np 
arr = np.array([10,20,30,40])

print(np.min(arr))
print(np.max(arr))
print(np.sum(arr))
print(np.mean(arr))
print(np.std(arr))
print(np.var(arr))
# Out:
# 10
# 40
# 100
# 25.0
# 11.180339887498949
# 125.0
