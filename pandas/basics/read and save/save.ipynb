# %%
import pandas as pd

data = {
    "name" : ['Rahul', 'Dev', 'Debu', 'Subhomoy'],
    "Age" : [20,22, 20,24],
    "City" : ['Chandpara', 'Kandi', 'Chandrakona', 'Uluberia']
}
df = pd.DataFrame(data)
print(df)

df.to_excel("output.xlsx", index= False)
# Out:
#        name  Age         City
# 0     Rahul   20    Chandpara
# 1       Dev   22        Kandi
# 2      Debu   20  Chandrakona
# 3  Subhomoy   24     Uluberia
