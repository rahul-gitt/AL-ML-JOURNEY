# %%
import pandas as pd

data = {
    "name" : ['Rahul', 'Dev', 'Debu', 'Subhomoy'],
    "Age" : [20,22, 20,24],
    "CGPA" : ['9.10', '9.25', '8.10', '8.5']
}

df = pd.DataFrame(data)
df.to_csv("output_csv.csv")

print(df)
# Out:
#        name  Age  CGPA
# 0     Rahul   20  9.10
# 1       Dev   22  9.25
# 2      Debu   20  8.10
# 3  Subhomoy   24   8.5
