# %%
# using tail print last 10 rows

import pandas as pd

df = pd.read_excel("fsi-2013.xlsx")
print("Display last 10 rows : ")
print(df.tail(10))
# Out:
# Display last 10 rows :
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 168    Australia 2013-01-01  169th   25.4                     1.7
# 169      Ireland 2013-01-01  170th   24.8                     1.8
# 170      Iceland 2013-01-01  171st   24.7                     1.0
# 171   Luxembourg 2013-01-01  172nd   23.3                     2.3
# 172  New Zealand 2013-01-01  173rd   22.7                     1.1
# 173      Denmark 2013-01-01  174th   21.9                     1.5
# 174       Norway 2013-01-01  175th   21.5                     2.7
# 175  Switzerland 2013-01-01  175th   21.5                     1.4
# 176       Sweden 2013-01-01  177th   19.7                     2.2
# 177      Finland 2013-01-01  178th   18.0                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 168                       1.6                  3.6          2.1
# 169                       1.3                  1.6          3.9
# ...
