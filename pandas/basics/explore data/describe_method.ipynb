# %%
'''describe():

describe() method is used to generate statistical 
summary of numerical columns in a DataFrame.'''

import pandas as pd

data = {
    "Name" : ['Rahul','Debu', 'Dev', 'Subho', 'Anshu', 'Simran', 'Souvik', 'Satak'],
    "Age" : [20,20,22,24,24,20,22,23],
    "Salary" : [70000, 40000, 50000, 45000, 35000, 30000, 80000, 60000],
    "Performance Score" : [95, 75, 80, 78, 72, 70, 89, 88]
} 
df = pd.DataFrame(data)

print(df.describe())
# Out:
#              Age        Salary  Performance Score
# count   8.000000      8.000000           8.000000
# mean   21.875000  51250.000000          80.875000
# std     1.726888  17474.471175           8.919281
# min    20.000000  30000.000000          70.000000
# 25%    20.000000  38750.000000          74.250000
# 50%    22.000000  47500.000000          79.000000
# 75%    23.250000  62500.000000          88.250000
# max    24.000000  80000.000000          95.000000
