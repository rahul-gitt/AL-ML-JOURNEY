# %%
# using head print first 10 rows
import pandas as pd

df = pd.read_excel("fsi-2013.xlsx")

print("First 10 rows : ")
print(df.head(10))
# Out:
# First 10 rows :
#                      Country       Year  Rank  Total  C1: Security Apparatus  \
# 0                    Somalia 2013-01-01   1st  113.9                     9.7
# 1  Congo Democratic Republic 2013-01-01   2nd  111.9                    10.0
# 2                      Sudan 2013-01-01   3rd  111.0                     9.8
# 3                South Sudan 2013-01-01   4th  110.6                     9.6
# 4                       Chad 2013-01-01   5th  109.0                     9.4
# 5                      Yemen 2013-01-01   6th  107.0                     9.8
# 6                Afghanistan 2013-01-01   7th  106.7                     9.9
# 7                      Haiti 2013-01-01   8th  105.8                     7.9
# 8   Central African Republic 2013-01-01   9th  105.3                     9.7
# 9                   Zimbabwe 2013-01-01  10th  105.2                     8.4
#
#    C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# ...
