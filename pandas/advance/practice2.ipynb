# %%
import pandas as pd

data = {
    "Name" : ['Rahul','Debu', 'Dev', 'Subho', 'Anshu', 'Simran', 'Souvik', 'Satak'],
    "Age" : [20,20,22,24,24,20,22,23],
    "Salary" : [70000, 40000, 50000, 45000, 35000, 30000, 80000, 60000],
    "Performance Score" : [95, 75, 80, 78, 72, 70, 89, 88]
} 
df = pd.DataFrame(data)

print(df.loc[1:6,['Age', 'Performance Score']])
print(df.loc[3])
# Out:
#    Age  Performance Score
# 1   20                 75
# 2   22                 80
# 3   24                 78
# 4   24                 72
# 5   20                 70
# 6   22                 89
# Name                 Subho
# Age                     24
# Salary               45000
# Performance Score       78
# Name: 3, dtype: object
