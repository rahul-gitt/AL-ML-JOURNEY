# %%
'''iloc[]:

iloc[] is used to access rows and columns
by using their integer positions.'''

import pandas as pd

data = {
    "Name" : ['Rahul','Debu', 'Dev', 'Subho', 'Anshu', 'Simran', 'Souvik', 'Satak'],
    "Age" : [20,20,22,24,24,20,22,23],
    "Salary" : [70000, 40000, 50000, 45000, 35000, 30000, 80000, 60000],
    "Performance Score" : [95, 75, 80, 78, 72, 70, 89, 88]
} 

df = pd.DataFrame(data)

print(df.iloc[2])
print(df.iloc[0:[0,3]])
# Out:
# Name                   Dev
# Age                     22
# Salary               50000
# Performance Score       80
# Name: 2, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 18
#      14
#      15 df = pd.DataFrame(data)
#      16
#      17 print(df.iloc[2])
# ---> 18 print(df.iloc[0:[0,3]])
#
# File c:\Users\ASUS\OneDrive\Desktop\AL-ML-JOURNEY\.venv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ASUS\OneDrive\Desktop\AL-ML-JOURNEY\.venv\Lib\site-packages\pandas\core\indexing.py:1750, in _iLocIndexer._getitem_axis(self, key, axis)
#    1744     raise IndexError(
#    1745         "DataFrame indexer is not allowed for .iloc\n"
#    1746         "Consider using .loc for automatic alignment."
#    1747     )
#    1749 if isinstance(key, slice):
# -> 1750     return self._get_slice_axis(key, axis=axis)
#    1752 if is_iterator(key):
#    1753     key = list(key)
#
# File c:\Users\ASUS\OneDrive\Desktop\AL-ML-JOURNEY\.venv\Lib\site-packages\pandas\core\indexing.py:1785, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1782     return obj.copy(deep=False)
#    1784 labels = obj._get_axis(axis)
# -> 1785 labels._validate_positional_slice(slice_obj)
#    1786 return self.obj._slice(slice_obj, axis=axis)
#
# File c:\Users\ASUS\OneDrive\Desktop\AL-ML-JOURNEY\.venv\Lib\site-packages\pandas\core\indexes\base.py:4041, in Index._validate_positional_slice(self, key)
#    4036 """
#    4037 For positional indexing, a slice must have either int or None
#    4038 for each of start, stop, and step.
#    4039 """
#    4040 self._validate_indexer("positional", key.start, "iloc")
# -> 4041 self._validate_indexer("positional", key.stop, "iloc")
#    4042 self._validate_indexer("positional", key.step, "iloc")
#
# File c:\Users\ASUS\OneDrive\Desktop\AL-ML-JOURNEY\.venv\Lib\site-packages\pandas\core\indexes\base.py:6864, in Index._validate_indexer(self, form, key, kind)
#    6859 """
#    6860 If we are positional indexer, validate that we have appropriate
#    6861 typed bounds must be an integer.
#    6862 """
#    6863 if not lib.is_int_or_none(key):
# -> 6864     self._raise_invalid_indexer(form, key)
#
# File c:\Users\ASUS\OneDrive\Desktop\AL-ML-JOURNEY\.venv\Lib\site-packages\pandas\core\indexes\base.py:4125, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4123 if reraise is not lib.no_default:
#    4124     raise TypeError(msg) from reraise
# -> 4125 raise TypeError(msg)
#
# TypeError: cannot do positional indexing on RangeIndex with these indexers [[0, 3]] of type list
