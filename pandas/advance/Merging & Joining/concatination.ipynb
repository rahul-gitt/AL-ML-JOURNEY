# %%
# concatination()
# vertical(row wise)

import pandas as pd
df1 = pd.DataFrame({
    'Name' : ['Rahul','Dev'],
    'Age' : [19,22]
})

df2 = pd.DataFrame({
    'Name': ['Debu','Subho']
})

result = pd.concat([df1,df2])
