# %%
import pandas as pd

data = {
    "Name" : ['Rahul','Debu', 'Dev', 'Subho', 'Anshu', 'Simran', 'Souvik', 'Satak'],
    "Age" : [20,20,22,24,24,20,22,23],
    "Salary" : [70000, 40000, 50000, 45000, 35000, 30000, 80000, 60000],
    "Performance Score" : [95, 75, 80, 78, 72, 70, 89, 88]
} 
df = pd.DataFrame(data)

print(df['Salary'])
print(df[['Name','Age']])
print("indexing : ")
print((df.loc[2:5, 'Name']),(2:5,'Salary'))
# Out:
# 0    70000
# 1    40000
# 2    50000
# 3    45000
# 4    35000
# 5    30000
# 6    80000
# 7    60000
# Name: Salary, dtype: int64
#      Name  Age
# 0   Rahul   20
# 1    Debu   20
# 2     Dev   22
# 3   Subho   24
# 4   Anshu   24
# 5  Simran   20
# 6  Souvik   22
# 7   Satak   23
# indexing :
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[13], line 14
#      10
#      11 print(df['Salary'])
#      12 print(df[['Name','Age']])
#      13 print("indexing : ")
# ---> 14 print((df.loc[2:5, 'Name', 'Salary']))
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
# ...
